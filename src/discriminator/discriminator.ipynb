# %%
from keras.models import Model
from keras.layers import Input, Conv2D, Activation, LeakyReLU, Add, Dense, Reshape

# %%
class AnimeDiscriminatorFactory(object):
    """
        Discriminator Factory Class that creates the model described here:
        https://arxiv.org/pdf/1708.05509.pdf
    """
    
    def build(self, input_shape):
        """
            Returns a Model described here: https://arxiv.org/pdf/1708.05509.pdf
            
            Args:
                input_same: A 3 length tuple describing (width, height, channel)
                
            Output:
                Keras Model
        """
        RESIDUAL_BLOCKS_PER_LAYER = 2
        LEAKY_RELU_ALPHA = 0.2
        MODULES = 5
        
        def intermediate_layer(layer, filters, kernel_size):
            """
                Create the intermediate layers between residual layers.
                
                Args:
                    layer:       Keras layer
                    filters:     output size as an integer
                    kernel_size: length 2 tuple
                
                Returns:
                    Keras layer
            """
            layer = Conv2D(filters=filters, kernel_size=kernel_size, strides=(2, 2), padding="same")(layer)
            layer = LeakyReLU(alpha=LEAKY_RELU_ALPHA)(layer)
            return layer
        
        
        def initial_layer(input_layer):
            """
                Facade for intermediate_layer for the first layer of the network.
                 
                Args:
                    input_layer: Keras Input Layer
                
                Returns:
                    Keras layer
            """
            INITIAL_LAYER_FILTER = 32
            INITIAL_KERNEL_SIZE = (4, 4)
            return intermediate_layer(input_layer, INITIAL_LAYER_FILTER, INITIAL_KERNEL_SIZE)
        
#         def common_layer(layer):
#             layer = BatchNormalization()(layer)
#             layer = LeakyReLU(alpha=LEAKY_RELU_ALPHA)(layer)
#             return layer
        
        
        def residual_block(layer, filters):
            """
                Residual Block consisting of
                    Conv2D -> LeakyReLU -> Conv2D -> LeakyReLU -> Residual Addition
                
                Args:
                    layer:   Keras Layer
                    filters: output size as an integer
                
                Returns:
                    Keras layer
            """
            shortcut = layer
            layer = Conv2D(filters=filters, kernel_size=(3, 3), strides=(1, 1), padding="same")(layer)
            layer = LeakyReLU(alpha=LEAKY_RELU_ALPHA)(layer)
            layer = Conv2D(filters=filters, kernel_size=(3, 3), strides=(1, 1), padding="same")(layer)
            
            layer = Add()([layer, shortcut])
            layer = LeakyReLU(alpha=LEAKY_RELU_ALPHA)(layer)
            return layer
        
        
        def residual_layer(layer, number, filters):
            """
                Facade for residual block.
                
                Creates Residual layer with specified number of residual blocks
                
                Args:
                    layer:   Keras layer
                    number:  number of residual blocks in layer
                    filters: output size as an integer
                
                Returns:
                    Keras layer
            """
            for _ in range(number):
                layer = residual_block(layer, filters)
            return layer
        
                
        # NOTE: notation kxnysz
        # - k specifies that the convolution layer has kernel_size x
        # - n specifies that the convolution layer has y feature maps
        # - s specifies that the convolution layer has stride z
        
        inputs = Input(shape=input_shape)

        filters = 32
        # initial layer k4n32s2
        layer = initial_layer(inputs)
        for i in range(MODULES):
            layer = residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
            filters *= 2
            
            intermediate_kernel_size = (3, 3)
            if i < 2:
                intermediate_kernel_size = (4, 4)
            layer = intermediate_layer(layer, filters, intermediate_kernel_size)
            
        layer = Dense(1, activation="sigmoid")(layer)
        outputs = Reshape((1, ))(layer)
        
        return Model(inputs=inputs, outputs=outputs)
        
        # What the loop should be doing.
#         # 2 residual blocks (0)
#         # A residual block is 2 * k3n32s1
#         layer = residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
        
#         # intermediate layer k4n64s2
#         filters *= 2
#         layer = intermediate_layer(layer, filters, (4, 4))
        
#         # 2 residual blocks k3n64s1 (1)
#         layer = residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
        
#         # intermediate layer k4n128s2
#         layer = intermediate_layer(layer, 128, (4, 4))
        
#         # 2 residual block k3n128s1 (2)
#         filters *= 2
#         layer = residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
        
#         # intermediate layer k3n256s2
#         layer = intermediate_layer(layer, 256, (3, 3))
        
#         # 2 residual block k3n256s1 (3)
#         filters *= 2
#         residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
        
#         # intermediate layer k3n512s2
#         layer = intermediate_layer(layer, 512, (3, 3))
        
#         # 2 residual block k3n512s1 (4)
#         filters *= 2
#         residual_layer(layer, RESIDUAL_BLOCKS_PER_LAYER, filters)
        
#         # intermediate layer k3n1024s2
#         layer = intermediate_layer(layer, 1024, (3, 3))
        
#         outputs = Dense(2, activation="sigmoid")(layer)      
#         return Model(inputs=inputs, outputs=outputs)

# %%
expected_anime_image = (64, 64, 3)
discriminator_factory = AnimeDiscriminatorFactory()
model = discriminator_factory.build(expected_anime_image)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 64, 64, 3)     0
# ____________________________________________________________________________________________________
# conv2d_53 (Conv2D)               (None, 32, 32, 32)    1568        input_3[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)       (None, 32, 32, 32)    0           conv2d_53[0][0]
# ____________________________________________________________________________________________________
# conv2d_54 (Conv2D)               (None, 32, 32, 32)    9248        leaky_re_lu_53[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)       (None, 32, 32, 32)    0           conv2d_54[0][0]
# ____________________________________________________________________________________________________
# conv2d_55 (Conv2D)               (None, 32, 32, 32)    9248        leaky_re_lu_54[0][0]
# ____________________________________________________________________________________________________
# add_21 (Add)                     (None, 32, 32, 32)    0           conv2d_55[0][0]
#                                                                    leaky_re_lu_53[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)       (None, 32, 32, 32)    0           add_21[0][0]
# ____________________________________________________________________________________________________
# conv2d_56 (Conv2D)               (None, 32, 32, 32)    9248        leaky_re_lu_55[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)       (None, 32, 32, 32)    0           conv2d_56[0][0]
# ____________________________________________________________________________________________________
# conv2d_57 (Conv2D)               (None, 32, 32, 32)    9248        leaky_re_lu_56[0][0]
# ____________________________________________________________________________________________________
# add_22 (Add)                     (None, 32, 32, 32)    0           conv2d_57[0][0]
#                                                                    leaky_re_lu_55[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)       (None, 32, 32, 32)    0           add_22[0][0]
# ____________________________________________________________________________________________________
# conv2d_58 (Conv2D)               (None, 16, 16, 64)    32832       leaky_re_lu_57[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)       (None, 16, 16, 64)    0           conv2d_58[0][0]
# ____________________________________________________________________________________________________
# conv2d_59 (Conv2D)               (None, 16, 16, 64)    36928       leaky_re_lu_58[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)       (None, 16, 16, 64)    0           conv2d_59[0][0]
# ____________________________________________________________________________________________________
# conv2d_60 (Conv2D)               (None, 16, 16, 64)    36928       leaky_re_lu_59[0][0]
# ____________________________________________________________________________________________________
# add_23 (Add)                     (None, 16, 16, 64)    0           conv2d_60[0][0]
#                                                                    leaky_re_lu_58[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)       (None, 16, 16, 64)    0           add_23[0][0]
# ____________________________________________________________________________________________________
# conv2d_61 (Conv2D)               (None, 16, 16, 64)    36928       leaky_re_lu_60[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)       (None, 16, 16, 64)    0           conv2d_61[0][0]
# ____________________________________________________________________________________________________
# conv2d_62 (Conv2D)               (None, 16, 16, 64)    36928       leaky_re_lu_61[0][0]
# ____________________________________________________________________________________________________
# add_24 (Add)                     (None, 16, 16, 64)    0           conv2d_62[0][0]
#                                                                    leaky_re_lu_60[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)       (None, 16, 16, 64)    0           add_24[0][0]
# ____________________________________________________________________________________________________
# conv2d_63 (Conv2D)               (None, 8, 8, 128)     131200      leaky_re_lu_62[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)       (None, 8, 8, 128)     0           conv2d_63[0][0]
# ____________________________________________________________________________________________________
# conv2d_64 (Conv2D)               (None, 8, 8, 128)     147584      leaky_re_lu_63[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)       (None, 8, 8, 128)     0           conv2d_64[0][0]
# ____________________________________________________________________________________________________
# conv2d_65 (Conv2D)               (None, 8, 8, 128)     147584      leaky_re_lu_64[0][0]
# ____________________________________________________________________________________________________
# add_25 (Add)                     (None, 8, 8, 128)     0           conv2d_65[0][0]
#                                                                    leaky_re_lu_63[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)       (None, 8, 8, 128)     0           add_25[0][0]
# ____________________________________________________________________________________________________
# conv2d_66 (Conv2D)               (None, 8, 8, 128)     147584      leaky_re_lu_65[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)       (None, 8, 8, 128)     0           conv2d_66[0][0]
# ____________________________________________________________________________________________________
# conv2d_67 (Conv2D)               (None, 8, 8, 128)     147584      leaky_re_lu_66[0][0]
# ____________________________________________________________________________________________________
# add_26 (Add)                     (None, 8, 8, 128)     0           conv2d_67[0][0]
#                                                                    leaky_re_lu_65[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)       (None, 8, 8, 128)     0           add_26[0][0]
# ____________________________________________________________________________________________________
# conv2d_68 (Conv2D)               (None, 4, 4, 256)     295168      leaky_re_lu_67[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)       (None, 4, 4, 256)     0           conv2d_68[0][0]
# ____________________________________________________________________________________________________
# conv2d_69 (Conv2D)               (None, 4, 4, 256)     590080      leaky_re_lu_68[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)       (None, 4, 4, 256)     0           conv2d_69[0][0]
# ____________________________________________________________________________________________________
# conv2d_70 (Conv2D)               (None, 4, 4, 256)     590080      leaky_re_lu_69[0][0]
# ____________________________________________________________________________________________________
# add_27 (Add)                     (None, 4, 4, 256)     0           conv2d_70[0][0]
#                                                                    leaky_re_lu_68[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)       (None, 4, 4, 256)     0           add_27[0][0]
# ____________________________________________________________________________________________________
# conv2d_71 (Conv2D)               (None, 4, 4, 256)     590080      leaky_re_lu_70[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)       (None, 4, 4, 256)     0           conv2d_71[0][0]
# ____________________________________________________________________________________________________
# conv2d_72 (Conv2D)               (None, 4, 4, 256)     590080      leaky_re_lu_71[0][0]
# ____________________________________________________________________________________________________
# add_28 (Add)                     (None, 4, 4, 256)     0           conv2d_72[0][0]
#                                                                    leaky_re_lu_70[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)       (None, 4, 4, 256)     0           add_28[0][0]
# ____________________________________________________________________________________________________
# conv2d_73 (Conv2D)               (None, 2, 2, 512)     1180160     leaky_re_lu_72[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)       (None, 2, 2, 512)     0           conv2d_73[0][0]
# ____________________________________________________________________________________________________
# conv2d_74 (Conv2D)               (None, 2, 2, 512)     2359808     leaky_re_lu_73[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)       (None, 2, 2, 512)     0           conv2d_74[0][0]
# ____________________________________________________________________________________________________
# conv2d_75 (Conv2D)               (None, 2, 2, 512)     2359808     leaky_re_lu_74[0][0]
# ____________________________________________________________________________________________________
# add_29 (Add)                     (None, 2, 2, 512)     0           conv2d_75[0][0]
#                                                                    leaky_re_lu_73[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)       (None, 2, 2, 512)     0           add_29[0][0]
# ____________________________________________________________________________________________________
# conv2d_76 (Conv2D)               (None, 2, 2, 512)     2359808     leaky_re_lu_75[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)       (None, 2, 2, 512)     0           conv2d_76[0][0]
# ____________________________________________________________________________________________________
# conv2d_77 (Conv2D)               (None, 2, 2, 512)     2359808     leaky_re_lu_76[0][0]
# ____________________________________________________________________________________________________
# add_30 (Add)                     (None, 2, 2, 512)     0           conv2d_77[0][0]
#                                                                    leaky_re_lu_75[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)       (None, 2, 2, 512)     0           add_30[0][0]
# ____________________________________________________________________________________________________
# conv2d_78 (Conv2D)               (None, 1, 1, 1024)    4719616     leaky_re_lu_77[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)       (None, 1, 1, 1024)    0           conv2d_78[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 1, 1, 1)       1025        leaky_re_lu_78[0][0]
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 1)             0           dense_3[0][0]
# ====================================================================================================
# Total params: 18,936,161
# Trainable params: 18,936,161
# Non-trainable params: 0
# ____________________________________________________________________________________________________
